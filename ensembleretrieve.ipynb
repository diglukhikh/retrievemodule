# %% [markdown]
# <a href="https://colab.research.google.com/github/diglukhikh/retrievemodule/blob/main/ensembleretrieve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, concatenate, Input, average
import numpy

# %% [markdown]
# 4 модели

# %%
dataset = numpy.loadtxt("train.csv", delimiter=",")
s = dataset.shape[1]
print(s)
a = int((s - 1) / 2)
print(f"размер {a}")
X1 = dataset[:, 0:a].astype(int)
X = dataset[:, 0:a*2].astype(int)
X2 = dataset[:, a:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset[:, a * 2]
print(Y)

# формируем входной вектор - разница между соответствующими позициями векторов X1, X2
# X_in1 = 1-abs(X1-X2)
X_in1 = abs(X1 - X2)

X_in2 = abs(X1 + X2)
X_in3 = X

model_in1 = Input(shape=(a,))
model_out1111 = Dense(512, input_dim=a, activation="relu", name="layer1111")(model_in1)
model_out111 = Dense(256, activation="relu", name="layer111")(model_out1111)
model_out11 = Dense(128, activation="swish", name="layer11")(model_out111)
model_out1 = Dense(56, activation="relu", name="layer1")(model_out11)
# model1 = Model(model_in1, model_out1)

model_in2 = Input(shape=(a,))
model_out22 = Dense(512, input_dim=a, activation="relu", name="layer2")(model_in2)
model_out222 = Dense(256, activation="swish", name="layer22")(model_out22)
model_out2222 = Dense(128, activation="relu", name="layer222")(model_out222)
model_out2 = Dense(56, activation="swish", name="layer2222")(model_out2222)
# model2 = Model(model_in2, model_out2)

model_in3 = Input(shape=(a,))
model_out33 = Dense(128, input_dim=a, activation="relu", name="layer3")(model_in3)
model_out3 = Dense(56, activation="relu", name="layer333")(model_out33)
# model1 = Model(model_in1, model_out1)

model_in4 = Input(shape=(a,))
model_out44 = Dense(256, input_dim=a, activation="relu", name="layer4")(model_in4)
model_out444 = Dense(128, activation="swish", name="layer444")(model_out44)
model_out4 = Dense(56, activation="relu", name="layer44")(model_out444)

concatenated = average([model_out1, model_out2, model_out3,model_out4])
out = Dense(1, activation="relu", name="outputlayer")(concatenated)
merged_model = Model([model_in1, model_in2, model_in3,model_in4], out)
merged_model.compile(loss='MeanSquaredError', optimizer='RMSprop', metrics=['mape'])
merged_model.fit([X_in1, X_in2, X_in1,X_in1], Y, batch_size=15, epochs=20, verbose=1, validation_split=0.3)

dataset_valid = numpy.loadtxt("valid20_7.csv", delimiter=",")
s = dataset_valid.shape[1]
print(s)
a = int((s - 1) / 2)
X1 = dataset_valid[:, 0:a].astype(int)
X2 = dataset_valid[:, a:a * 2].astype(int)
X = dataset_valid[:, 0:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset_valid[:, a * 2]

X_in_valid1 = abs(X1 - X2)
X_in_valid2 = abs(X1 + X2)
X_in_valid3 = X

predictions = merged_model.predict([X_in_valid1,X_in_valid2,X_in_valid1,X_in_valid1])

print(Y)  # это фактические значения из файла

aa = numpy.around(predictions, decimals=3)
print(aa)

scores_valid = merged_model.evaluate([X_in_valid1,X_in_valid2,X_in_valid1,X_in_valid1], Y)
print("\n%s: %.2f%%" % (merged_model.metrics_names[1], scores_valid[1]))
# Out:
# 85
# размер 42
# (2082, 42)
# (2082, 42)
# [0.756 0.756 0.822 ... 0.86  0.93  0.93 ]
# Epoch 1/20
# 98/98 [==============================] - 3s 11ms/step - loss: 0.0265 - mape: 19.0037 - val_loss: 0.0373 - val_mape: 20.7164
# Epoch 2/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0054 - mape: 9.9386 - val_loss: 0.0150 - val_mape: 12.3496
# Epoch 3/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0030 - mape: 7.2245 - val_loss: 0.0066 - val_mape: 7.4159
# Epoch 4/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0023 - mape: 6.3948 - val_loss: 0.0060 - val_mape: 6.7266
# Epoch 5/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0016 - mape: 5.0760 - val_loss: 0.0037 - val_mape: 5.1318
# Epoch 6/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0013 - mape: 4.7539 - val_loss: 0.0065 - val_mape: 7.1683
# Epoch 7/20
# 98/98 [==============================] - 1s 10ms/step - loss: 0.0011 - mape: 4.2899 - val_loss: 0.0045 - val_mape: 5.9919
# Epoch 8/20
# 98/98 [==============================] - 1s 9ms/step - loss: 9.1200e-04 - mape: 4.0222 - val_loss: 0.0057 - val_mape: 6.6647
# Epoch 9/20
# 98/98 [==============================] - 1s 9ms/step - loss: 8.1429e-04 - mape: 3.6476 - val_loss: 0.0047 - val_mape: 6.1849
# Epoch 10/20
# 98/98 [==============================] - 1s 9ms/step - loss: 6.5657e-04 - mape: 3.4038 - val_loss: 0.0084 - val_mape: 8.5035
# Epoch 11/20
# 98/98 [==============================] - 1s 11ms/step - loss: 6.2702e-04 - mape: 3.2857 - val_loss: 0.0040 - val_mape: 5.6439
# Epoch 12/20
# 98/98 [==============================] - 2s 16ms/step - loss: 5.6587e-04 - mape: 3.1207 - val_loss: 0.0053 - val_mape: 6.7682
# Epoch 13/20
# 98/98 [==============================] - 1s 11ms/step - loss: 5.1078e-04 - mape: 2.9022 - val_loss: 0.0027 - val_mape: 4.4788
# Epoch 14/20
# 98/98 [==============================] - 1s 9ms/step - loss: 4.6627e-04 - mape: 2.8510 - val_loss: 0.0048 - val_mape: 6.0902
# Epoch 15/20
# 98/98 [==============================] - 1s 10ms/step - loss: 4.2445e-04 - mape: 2.6105 - val_loss: 0.0040 - val_mape: 5.6792
# Epoch 16/20
# 98/98 [==============================] - 1s 9ms/step - loss: 4.1881e-04 - mape: 2.6291 - val_loss: 0.0036 - val_mape: 5.1429
# Epoch 17/20
# 98/98 [==============================] - 1s 9ms/step - loss: 3.8398e-04 - mape: 2.5206 - val_loss: 0.0031 - val_mape: 4.9077
# Epoch 18/20
# 98/98 [==============================] - 1s 10ms/step - loss: 3.7984e-04 - mape: 2.6124 - val_loss: 0.0056 - val_mape: 6.9005
# Epoch 19/20
# 98/98 [==============================] - 1s 10ms/step - loss: 3.8388e-04 - mape: 2.4984 - val_loss: 0.0038 - val_mape: 5.5081
# Epoch 20/20
# 98/98 [==============================] - 1s 9ms/step - loss: 3.1952e-04 - mape: 2.3040 - val_loss: 0.0038 - val_mape: 5.6082
# 85
# (4, 42)
# (4, 42)
# 1/1 [==============================] - 0s 155ms/step
# [0.95 0.81 0.77 0.9 ]
# [[0.878]
#  [0.807]
#  [0.738]
#  [0.878]]
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0017 - mape: 3.6137
#
# mape: 3.61%

# %% [markdown]
# 3 модели

# %%
dataset = numpy.loadtxt("train.csv", delimiter=",")
s = dataset.shape[1]
print(s)
a = int((s - 1) / 2)
print(f"размер {a}")
X1 = dataset[:, 0:a].astype(int)
X = dataset[:, 0:a*2].astype(int)
X2 = dataset[:, a:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset[:, a * 2]
print(Y)

# формируем входной вектор - разница между соответствующими позициями векторов X1, X2
# X_in1 = 1-abs(X1-X2)
X_in1 = abs(X1 - X2)

X_in2 = abs(X1 + X2)
X_in3 = X

model_in1 = Input(shape=(a,))
model_out1111 = Dense(512, input_dim=a, activation="relu", name="layer1111")(model_in1)
model_out111 = Dense(256, activation="relu", name="layer111")(model_out1111)
model_out11 = Dense(128, activation="swish", name="layer11")(model_out111)
model_out1 = Dense(56, activation="relu", name="layer1")(model_out11)
# model1 = Model(model_in1, model_out1)

model_in2 = Input(shape=(a,))
model_out22 = Dense(512, input_dim=a, activation="relu", name="layer2")(model_in2)
model_out222 = Dense(256, activation="swish", name="layer22")(model_out22)
model_out2222 = Dense(128, activation="relu", name="layer222")(model_out222)
model_out2 = Dense(56, activation="swish", name="layer2222")(model_out2222)
# model2 = Model(model_in2, model_out2)

model_in4 = Input(shape=(a,))
model_out44 = Dense(256, input_dim=a, activation="relu", name="layer4")(model_in4)
model_out444 = Dense(128, activation="swish", name="layer444")(model_out44)
model_out4 = Dense(56, activation="relu", name="layer44")(model_out444)

concatenated = concatenate([model_out1, model_out2,model_out4])
out = Dense(1, activation="relu", name="outputlayer")(concatenated)
merged_model = Model([model_in1, model_in2,model_in4], out)
merged_model.compile(loss='MeanSquaredError', optimizer='RMSprop', metrics=['mape'])
merged_model.fit([X_in1, X_in2,X_in1], Y, batch_size=15, epochs=20, verbose=1, validation_split=0.3)

dataset_valid = numpy.loadtxt("valid20_7.csv", delimiter=",")
s = dataset_valid.shape[1]
print(s)
a = int((s - 1) / 2)
X1 = dataset_valid[:, 0:a].astype(int)
X2 = dataset_valid[:, a:a * 2].astype(int)
X = dataset_valid[:, 0:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset_valid[:, a * 2]

X_in_valid1 = abs(X1 - X2)
X_in_valid2 = abs(X1 + X2)
X_in_valid3 = X

predictions = merged_model.predict([X_in_valid1,X_in_valid2,X_in_valid1])

print(Y)  # это фактические значения из файла

aa = numpy.around(predictions, decimals=3)
print(aa)

scores_valid = merged_model.evaluate([X_in_valid1,X_in_valid2,X_in_valid1], Y)
print("\n%s: %.2f%%" % (merged_model.metrics_names[1], scores_valid[1]))
# Out:
# 85
# размер 42
# (2082, 42)
# (2082, 42)
# [0.756 0.756 0.822 ... 0.86  0.93  0.93 ]
# Epoch 1/20
# 98/98 [==============================] - 3s 20ms/step - loss: 0.0444 - mape: 21.0850 - val_loss: 0.0101 - val_mape: 9.2669
# Epoch 2/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0069 - mape: 11.6145 - val_loss: 0.0137 - val_mape: 11.5553
# Epoch 3/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0036 - mape: 8.1511 - val_loss: 0.0045 - val_mape: 5.9469
# Epoch 4/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0023 - mape: 6.4917 - val_loss: 0.0092 - val_mape: 9.2140
# Epoch 5/20
# 98/98 [==============================] - 1s 8ms/step - loss: 0.0020 - mape: 5.8048 - val_loss: 0.0071 - val_mape: 7.7417
# Epoch 6/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0016 - mape: 5.3926 - val_loss: 0.0043 - val_mape: 5.7772
# Epoch 7/20
# 98/98 [==============================] - 1s 8ms/step - loss: 0.0011 - mape: 4.4260 - val_loss: 0.0035 - val_mape: 5.4072
# Epoch 8/20
# 98/98 [==============================] - 1s 8ms/step - loss: 9.3019e-04 - mape: 3.8648 - val_loss: 0.0094 - val_mape: 9.7222
# Epoch 9/20
# 98/98 [==============================] - 1s 8ms/step - loss: 8.2354e-04 - mape: 3.8553 - val_loss: 0.0041 - val_mape: 5.9059
# Epoch 10/20
# 98/98 [==============================] - 1s 8ms/step - loss: 6.5101e-04 - mape: 3.3714 - val_loss: 0.0098 - val_mape: 9.8623
# Epoch 11/20
# 98/98 [==============================] - 1s 8ms/step - loss: 6.5475e-04 - mape: 3.3183 - val_loss: 0.0061 - val_mape: 7.2750
# Epoch 12/20
# 98/98 [==============================] - 1s 8ms/step - loss: 5.7372e-04 - mape: 3.1710 - val_loss: 0.0059 - val_mape: 7.1797
# Epoch 13/20
# 98/98 [==============================] - 1s 9ms/step - loss: 4.8023e-04 - mape: 2.8445 - val_loss: 0.0048 - val_mape: 6.4157
# Epoch 14/20
# 98/98 [==============================] - 1s 9ms/step - loss: 5.2865e-04 - mape: 2.9724 - val_loss: 0.0048 - val_mape: 6.5183
# Epoch 15/20
# 98/98 [==============================] - 1s 8ms/step - loss: 4.4667e-04 - mape: 2.7446 - val_loss: 0.0039 - val_mape: 5.6791
# Epoch 16/20
# 98/98 [==============================] - 1s 8ms/step - loss: 3.9199e-04 - mape: 2.6162 - val_loss: 0.0026 - val_mape: 4.5955
# Epoch 17/20
# 98/98 [==============================] - 1s 9ms/step - loss: 3.6467e-04 - mape: 2.3991 - val_loss: 0.0034 - val_mape: 5.2826
# Epoch 18/20
# 98/98 [==============================] - 1s 8ms/step - loss: 3.7240e-04 - mape: 2.6176 - val_loss: 0.0045 - val_mape: 6.0010
# Epoch 19/20
# 98/98 [==============================] - 1s 9ms/step - loss: 3.5949e-04 - mape: 2.3650 - val_loss: 0.0030 - val_mape: 4.9306
# Epoch 20/20
# 98/98 [==============================] - 1s 9ms/step - loss: 3.4117e-04 - mape: 2.4069 - val_loss: 0.0025 - val_mape: 4.3956
# 85
# (4, 42)
# (4, 42)
# 1/1 [==============================] - 0s 131ms/step
# [0.95 0.81 0.77 0.9 ]
# [[0.911]
#  [0.841]
#  [0.793]
#  [0.868]]
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0010 - mape: 3.6383
#
# mape: 3.64%

# %% [markdown]
# 2 модели

# %%
dataset = numpy.loadtxt("train.csv", delimiter=",")
s = dataset.shape[1]
print(s)
a = int((s - 1) / 2)
print(f"размер {a}")
X1 = dataset[:, 0:a].astype(int)
X = dataset[:, 0:a*2].astype(int)
X2 = dataset[:, a:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset[:, a * 2]
print(Y)

# формируем входной вектор - разница между соответствующими позициями векторов X1, X2
# X_in1 = 1-abs(X1-X2)
X_in1 = abs(X1 - X2)

X_in2 = abs(X1 + X2)
X_in3 = X

model_in1 = Input(shape=(a,))
model_out1111 = Dense(512, input_dim=a, activation="relu", name="layer1111")(model_in1)
model_out111 = Dense(256, activation="relu", name="layer111")(model_out1111)
model_out11 = Dense(128, activation="swish", name="layer11")(model_out111)
model_out1 = Dense(56, activation="relu", name="layer1")(model_out11)
# model1 = Model(model_in1, model_out1)

model_in2 = Input(shape=(a,))
model_out22 = Dense(512, input_dim=a, activation="relu", name="layer2")(model_in2)
model_out222 = Dense(256, activation="swish", name="layer22")(model_out22)
model_out2222 = Dense(128, activation="relu", name="layer222")(model_out222)
model_out2 = Dense(56, activation="swish", name="layer2222")(model_out2222)
# model2 = Model(model_in2, model_out2)

concatenated = concatenate([model_out1, model_out2])
out = Dense(1, activation="relu", name="outputlayer")(concatenated)
merged_model = Model([model_in1, model_in2], out)
merged_model.compile(loss='MeanSquaredError', optimizer='RMSprop', metrics=['mape'])
merged_model.fit([X_in1, X_in2], Y, batch_size=15, epochs=20, verbose=1, validation_split=0.3)

dataset_valid = numpy.loadtxt("valid20_7.csv", delimiter=",")
s = dataset_valid.shape[1]
print(s)
a = int((s - 1) / 2)
X1 = dataset_valid[:, 0:a].astype(int)
X2 = dataset_valid[:, a:a * 2].astype(int)
X = dataset_valid[:, 0:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset_valid[:, a * 2]

X_in_valid1 = abs(X1 - X2)
X_in_valid2 = abs(X1 + X2)
X_in_valid3 = X

predictions = merged_model.predict([X_in_valid1,X_in_valid1])

print(Y)  # это фактические значения из файла

aa = numpy.around(predictions, decimals=3)
print(aa)

scores_valid = merged_model.evaluate([X_in_valid1,X_in_valid1], Y)
print("\n%s: %.2f%%" % (merged_model.metrics_names[1], scores_valid[1]))
# Out:
# 85
# размер 42
# (2082, 42)
# (2082, 42)
# [0.756 0.756 0.822 ... 0.86  0.93  0.93 ]
# Epoch 1/20
# 98/98 [==============================] - 2s 11ms/step - loss: 0.0278 - mape: 19.0398 - val_loss: 0.0050 - val_mape: 6.4587
# Epoch 2/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0055 - mape: 9.7673 - val_loss: 0.0031 - val_mape: 5.0560
# Epoch 3/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0034 - mape: 8.0292 - val_loss: 0.0041 - val_mape: 5.5712
# Epoch 4/20
# 98/98 [==============================] - 1s 8ms/step - loss: 0.0021 - mape: 6.3034 - val_loss: 0.0045 - val_mape: 5.9460
# Epoch 5/20
# 98/98 [==============================] - 1s 8ms/step - loss: 0.0019 - mape: 5.5126 - val_loss: 0.0025 - val_mape: 4.5585
# Epoch 6/20
# 98/98 [==============================] - 1s 8ms/step - loss: 0.0015 - mape: 5.2538 - val_loss: 0.0043 - val_mape: 6.0074
# Epoch 7/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0012 - mape: 4.5029 - val_loss: 0.0105 - val_mape: 9.7399
# Epoch 8/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0010 - mape: 4.0956 - val_loss: 0.0032 - val_mape: 5.2726
# Epoch 9/20
# 98/98 [==============================] - 1s 8ms/step - loss: 8.2613e-04 - mape: 3.8923 - val_loss: 0.0040 - val_mape: 5.8137
# Epoch 10/20
# 98/98 [==============================] - 1s 9ms/step - loss: 7.6919e-04 - mape: 3.6591 - val_loss: 0.0040 - val_mape: 5.8892
# Epoch 11/20
# 98/98 [==============================] - 1s 9ms/step - loss: 6.8618e-04 - mape: 3.3988 - val_loss: 0.0106 - val_mape: 10.4476
# Epoch 12/20
# 98/98 [==============================] - 1s 8ms/step - loss: 6.7752e-04 - mape: 3.3105 - val_loss: 0.0070 - val_mape: 7.8357
# Epoch 13/20
# 98/98 [==============================] - 1s 8ms/step - loss: 5.6320e-04 - mape: 3.0032 - val_loss: 0.0044 - val_mape: 6.0754
# Epoch 14/20
# 98/98 [==============================] - 1s 9ms/step - loss: 5.4938e-04 - mape: 3.0015 - val_loss: 0.0038 - val_mape: 5.5441
# Epoch 15/20
# 98/98 [==============================] - 1s 9ms/step - loss: 4.9606e-04 - mape: 2.9331 - val_loss: 0.0028 - val_mape: 4.5791
# Epoch 16/20
# 98/98 [==============================] - 1s 8ms/step - loss: 4.4239e-04 - mape: 2.7811 - val_loss: 0.0032 - val_mape: 5.1344
# Epoch 17/20
# 98/98 [==============================] - 1s 8ms/step - loss: 4.7342e-04 - mape: 2.9037 - val_loss: 0.0026 - val_mape: 4.6491
# Epoch 18/20
# 98/98 [==============================] - 1s 8ms/step - loss: 4.0755e-04 - mape: 2.7720 - val_loss: 0.0028 - val_mape: 4.6383
# Epoch 19/20
# 98/98 [==============================] - 1s 9ms/step - loss: 4.0860e-04 - mape: 2.6024 - val_loss: 0.0025 - val_mape: 4.7075
# Epoch 20/20
# 98/98 [==============================] - 2s 16ms/step - loss: 3.7564e-04 - mape: 2.5974 - val_loss: 0.0031 - val_mape: 4.9348
# 85
# (4, 42)
# (4, 42)
# 1/1 [==============================] - 0s 149ms/step
# [0.95 0.81 0.77 0.9 ]
# [[0.619]
#  [0.606]
#  [0.551]
#  [0.601]]
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0722 - mape: 30.4343
#
# mape: 30.43%

# %% [markdown]
# 1 модель

# %%
dataset = numpy.loadtxt("train.csv", delimiter=",")
s = dataset.shape[1]
print(s)
a = int((s - 1) / 2)
print(f"размер {a}")
X1 = dataset[:, 0:a].astype(int)
X = dataset[:, 0:a*2].astype(int)
X2 = dataset[:, a:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset[:, a * 2]
print(Y)

# формируем входной вектор - разница между соответствующими позициями векторов X1, X2
# X_in1 = 1-abs(X1-X2)
X_in1 = abs(X1 - X2)

X_in2 = abs(X1 + X2)
X_in3 = X

model_in1 = Input(shape=(a,))
model_out1111 = Dense(512, input_dim=a, activation="relu", name="layer1111")(model_in1)
model_out111 = Dense(256, activation="relu", name="layer111")(model_out1111)
model_out11 = Dense(128, activation="swish", name="layer11")(model_out111)
model_out1 = Dense(56, activation="relu", name="layer1")(model_out11)
out = Dense(1, activation="relu", name="outputlayer")(model_out1)
model1 = Model(model_in1, out)

model1.compile(loss='MeanSquaredError', optimizer='RMSprop', metrics=['mape'])
model1.fit(X_in1, Y, batch_size=15, epochs=20, verbose=1, validation_split=0.3)

dataset_valid = numpy.loadtxt("valid20_7.csv", delimiter=",")
s = dataset_valid.shape[1]
print(s)
a = int((s - 1) / 2)
X1 = dataset_valid[:, 0:a].astype(int)
X2 = dataset_valid[:, a:a * 2].astype(int)
X = dataset_valid[:, 0:a * 2].astype(int)
print(X1.shape)
print(X2.shape)
Y = dataset_valid[:, a * 2]

X_in_valid1 = abs(X1 - X2)
X_in_valid2 = abs(X1 + X2)
X_in_valid3 = X

predictions = model1.predict(X_in_valid1)

print(Y)  # это фактические значения из файла

aa = numpy.around(predictions, decimals=3)
print(aa)

scores_valid = model1.evaluate(X_in_valid1, Y)
print("\n%s: %.2f%%" % (merged_model.metrics_names[1], scores_valid[1]))
# Out:
# 85
# размер 42
# (2082, 42)
# (2082, 42)
# [0.756 0.756 0.822 ... 0.86  0.93  0.93 ]
# Epoch 1/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.0302 - mape: 20.9107 - val_loss: 0.0259 - val_mape: 13.5577
# Epoch 2/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.0072 - mape: 10.9004 - val_loss: 0.0415 - val_mape: 20.6590
# Epoch 3/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0045 - mape: 8.5978 - val_loss: 0.0094 - val_mape: 8.0976
# Epoch 4/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.0030 - mape: 7.1279 - val_loss: 0.0105 - val_mape: 9.5631
# Epoch 5/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0021 - mape: 6.0871 - val_loss: 0.0105 - val_mape: 9.6812
# Epoch 6/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0018 - mape: 5.4896 - val_loss: 0.0031 - val_mape: 5.0368
# Epoch 7/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0013 - mape: 4.7696 - val_loss: 0.0039 - val_mape: 5.7302
# Epoch 8/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0013 - mape: 4.6156 - val_loss: 0.0061 - val_mape: 7.3389
# Epoch 9/20
# 98/98 [==============================] - 1s 6ms/step - loss: 9.5879e-04 - mape: 4.0925 - val_loss: 0.0029 - val_mape: 4.8448
# Epoch 10/20
# 98/98 [==============================] - 1s 6ms/step - loss: 8.6442e-04 - mape: 3.9091 - val_loss: 0.0023 - val_mape: 4.3925
# Epoch 11/20
# 98/98 [==============================] - 1s 5ms/step - loss: 7.4888e-04 - mape: 3.4284 - val_loss: 0.0032 - val_mape: 5.2900
# Epoch 12/20
# 98/98 [==============================] - 1s 5ms/step - loss: 8.2430e-04 - mape: 3.6335 - val_loss: 0.0032 - val_mape: 5.2278
# Epoch 13/20
# 98/98 [==============================] - 1s 6ms/step - loss: 6.2662e-04 - mape: 3.3241 - val_loss: 0.0029 - val_mape: 5.0293
# Epoch 14/20
# 98/98 [==============================] - 1s 5ms/step - loss: 6.4367e-04 - mape: 3.2975 - val_loss: 0.0023 - val_mape: 4.4055
# Epoch 15/20
# 98/98 [==============================] - 1s 6ms/step - loss: 5.3045e-04 - mape: 3.0668 - val_loss: 0.0031 - val_mape: 5.1774
# Epoch 16/20
# 98/98 [==============================] - 1s 5ms/step - loss: 4.8926e-04 - mape: 2.8504 - val_loss: 0.0034 - val_mape: 5.1954
# Epoch 17/20
# 98/98 [==============================] - 1s 5ms/step - loss: 5.1096e-04 - mape: 2.9778 - val_loss: 0.0021 - val_mape: 4.1815
# Epoch 18/20
# 98/98 [==============================] - 1s 6ms/step - loss: 4.7406e-04 - mape: 2.8738 - val_loss: 0.0057 - val_mape: 7.3937
# Epoch 19/20
# 98/98 [==============================] - 1s 5ms/step - loss: 4.4281e-04 - mape: 2.7718 - val_loss: 0.0024 - val_mape: 4.4338
# Epoch 20/20
# 98/98 [==============================] - 0s 5ms/step - loss: 4.4385e-04 - mape: 2.7769 - val_loss: 0.0028 - val_mape: 4.8965
# 85
# (4, 42)
# (4, 42)
# 1/1 [==============================] - 0s 72ms/step
# [0.95 0.81 0.77 0.9 ]
# [[0.911]
#  [0.877]
#  [0.823]
#  [0.919]]
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0023 - mape: 5.3139
#
# mape: 5.31%
